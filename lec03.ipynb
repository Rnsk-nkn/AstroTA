# %%
from google.colab import drive
drive.mount("/TA")

# %%
ls /TA/MyDrive/TA/

# %%
import matplotlib . pyplot as plt
import math
ld = open ("/TA/MyDrive/TA/hipparcos.dat")
lines = ld.readlines ()
ld.close ()
x = []
y = []
for line in lines :
    vapp = float ( line [129:136])
    bv = float ( line [152:158])
    d=1000/float(line[43:50])
    v=vapp+5-5*math.log10(d)
    #if bv != 0.:
    if bv == 0.:
        x.append (bv)
        y.append (v)

plt. scatter (x,y,s =1)
x = []
y = []   
for line in lines :
    vapp = float ( line [129:136])
    bv = float ( line [152:158])
    d=1000/float(line[43:50])
    v=vapp+5-5*math.log10(d)
    if bv != 0.:
    #if bv == 0.:
        x.append (bv)
        y.append (v)
plt. xlim ( -0.5 ,2.5)
plt. ylim (16 , -2)
plt. scatter (x,y,s =1)
plt. show ()

# %%
cat /TA/MyDrive/TA/hipparcos.txt

# %%
import matplotlib . pyplot as plt
import math
ld = open ("/TA/MyDrive/TA/hipparcos.dat")
lines = ld.readlines ()
ld.close ()
mind=1000000.
for line in lines :
    d=1000/float(line[43:50])
    #print(d)
    if mind>d:
      mind=d
      print(line[0:6],mind,"pc",float(line[43:50]))

# %%
#d=a/tan(p)
#a=d*tan(p)
print(100*math.tan((796.92/1000)*(math.pi/180/3600))*1000) #miliarcsecond radian milisec km=>m

# %%
 1.25483109e0*3.0857e13 #pc=>km
print(1.25483109e0*3.0857e13/37e4) #pc=>km
#x 1e8

print(10e-2*(1.25483109e0*3.0857e13/37e4)/1e3)

# %%
import matplotlib . pyplot as plt
import math
ld = open ("/TA/MyDrive/TA/hipparcos.dat")
lines = ld.readlines ()
ld.close ()
x = []
y = []
for line in lines :
    vapp = float ( line [129:136])
    #bv = float ( line [152:158])
    vi = float ( line [165:171])
    d=1000/float(line[43:50])
    v=vapp+5-5*math.log10(d)
    if vi != 0. and d<=25.:
    #if bv != 0. and d>25.:
        x.append (vi)
        y.append (v)
#plt. xlim ( -0.5 ,2.5)
plt. ylim (16 , -4)
plt. scatter (x,y,s =1)

ld = open ("/TA/MyDrive/TA/ngc1754.dat")
lines = ld.readlines ()
ld.close ()
x1 = []
y1 = []
for line in lines :
    vapp = float (line [74:82])
    iapp = float (line [83:91])
    if vapp !=-999 and iapp !=-999:
        x1.append (vapp-iapp)
        y1.append (vapp-21)#
plt. scatter (x1,y1,s =1)

plt. show ()

# %%
import matplotlib . pyplot as plt1
import math
ld = open ("/TA/MyDrive/TA/hipparcos.dat")
lines = ld.readlines ()
ld.close ()
x = []
y = []
for line in lines :
    vapp = float ( line [129:136])
    #bv = float ( line [152:158])
    vi = float ( line [165:171])
    d=1000/float(line[43:50])
    v=vapp+5-5*math.log10(d)
    if vi != 0. and d<=25.:
    #if bv != 0. and d>25.:
        x.append (vi)
        y.append (v)
#plt. xlim ( -0.5 ,2.5)
#plt. ylim (16 , -2)
plt. scatter (x,y,s =1)

ld = open ("/TA/MyDrive/TA/ngc1754.dat")
lines = ld.readlines ()
ld.close ()
x1 = []
y1 = []
d2=50*1000
for line in lines :
    vapp = float (line [74:82])
    iapp = float (line [83:91])
    if vapp !=-999 and iapp !=-999:
        x1.append (vapp-iapp+0.4)
        y1.append (vapp+5-5*math.log10(d２))#
plt. scatter (x1,y1,s =0.1)

plt. show ()

# %%
import matplotlib . pyplot as plt
import math
ld = open ("/TA/MyDrive/TA/evs_cat.dat")
lines = ld.readlines ()
ld.close ()
x1 = []
y1 = []
x2 = []
y2 = []
d2=140*1000 #kPc
d3=2200*1000 #kPc
vmax1=0.
vmax2=0.
for line in lines :
    num = line [0:3]
    app = float ( line [47:52])
    day=float(line[77:90])
    if num=="089" :#and vmax1<app:
      vmax1=app+5-5*math.log10(d２)
      y1.append(vmax1)
      day1=math.log10(day)
      x1.append(day1)
    if num=="091" :#and vmax2<app:
      vmax2=app+5-5*math.log10(d３)
      y2.append(vmax2)
      day2=math.log10(day)
      x2.append(day2)
    #x.append (math.log(day))
    #y.append (app)
#plt. xlim ( -0.5 ,2.5)
plt. ylim (0, -10)
plt. scatter (x1,y1,s =3)
plt. scatter (x2,y2,s =3)


plt. show ()

# %%
import matplotlib . pyplot as plt
import math
ld = open ("/TA/MyDrive/TA/zcat.dat")
lines = ld.readlines ()
ld.close ()
x1 = []
y1 = []
y1 = []
x2 = []
y2 = []
d2=140*1000 #kPc
d3=2200*1000 #kPc
vmax1=0.
vmax2=0.
H0=80.
for line in lines :
  a1=line[11:13]
  a2=line[13:15]
  a3=line[15:19]
  b1=line[19:22]
  b2=line[22:24]
  vs=line[31:36]
  sp1=" "
  sp2="  "
  sp3="   "
  sp4="    "
  sp5="     "
  sp6="      "
  if a1!=sp3 and a2!=sp3 and a3!=sp5 and b1!=sp4 and b2!=sp3 and vs!=sp5:
    #赤経 8 時から 17 時、赤緯 25 度から 35 度、後退速度15000km s−1 以内の
    a10=float(a1)
    a1=float(a1)*360/24
    a2=float(a2)*360/24/60
    a3=float(a3)*360/24/60/60
    b1=float(b1)
    b2=float(b2)/60
    #print("/"+vs+"/")
    vs=float(vs)
    a=a1+a2+a3
    b=b1+b2
    if a10>=8 and a10<17 and b>25 and b<35 and vs<15000:
      x1.append(H0*vs*math.cos(math.radians(a)))
      y1.append(H0*vs*math.sin(math.radians(a)))
      #print(a,b)

plt. xlim ( -1e6 ,1e6)
plt. ylim (0e6, -1.25
           e6)
plt. scatter (y1,x1,s =3)
plt. scatter (x2,y2,s =3)


plt. show ()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
ld = open ("/TA/MyDrive/TA/zcat.dat")
lines = ld.readlines ()
ld.close ()
x1 = []
y1 = []
z1 = []
x2 = []
y2 = []
d2=140*1000 #kPc
d3=2200*1000 #kPc
vmax1=0.
vmax2=0.
H0=80.
for line in lines :
  a1=line[11:13]
  a2=line[13:15]
  a3=line[15:19]
  b1=line[19:22]
  b2=line[22:24]
  vs=line[31:36]
  sp1=" "
  sp2="  "
  sp3="   "
  sp4="    "
  sp5="     "
  sp6="      "
  if a1!=sp3 and a2!=sp3 and a3!=sp5 and b1!=sp4 and b2!=sp3 and vs!=sp5:
    #赤経 8 時から 17 時、赤緯 25 度から 35 度、後退速度15000km s−1 以内の
    a10=float(a1)
    a1=float(a1)*360/24
    a2=float(a2)*360/24/60
    a3=float(a3)*360/24/60/60
    b1=float(b1)
    b2=float(b2)/60
    #print("/"+vs+"/")
    vs=float(vs)
    a=a1+a2+a3
    b=b1+b2
    ar=(math.radians(a))
    br=(math.radians(b))
    if a10>=8 and a10<17 and b>25 and b<35 and vs<15000:
      x1.append(H0*vs*math.cos(ar)*math.cos(br))
      y1.append(H0*vs*math.cos(ar)*math.sin(br))
      z1.append(H0*vs*math.sin(br))
      #print(a,b)



fig = plt.figure()
fig = plt.figure()
ax = Axes3D(fig)
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x1, y1, z1)


plt. show ()

# %%
    # Convert latitude, longitude to radians
    lat_r = math.radians(latitude)
    lon_r = math.radians(longitude)

    # Calculate 3D position
    x = elevation * math.cos(lat_r) * math.cos(lon_r)
    y = elevation * math.cos(lat_r) * math.sin(lon_r)
    z = elevation * math.sin(lat_r)

    return (x, y, z)

# %%
#kadai3あ

# %%
#銀河名 後退速度 (km s−1) mV − MV(等級) 銀経 (度) 銀緯 (度)
import numpy as np
ginga=[["M31", -298 ,21 ,121 ,-22], #121 really?
["NGC300" ,145 ,26.66, 299 ,-79],
["M33", -182, 24.64 ,134 ,-31],
["NGC925", 554 ,29.84 ,144 ,-25],
["NGC1365" ,1639 ,31.35, 238 ,-55],
["NGC2090" ,936 ,30.45 ,239 ,-27],
["NGC2403" ,132 ,27.51 ,150 ,29],
["NGC2541" ,553, 30.47 ,170 ,33],
["M81", -43, 27.80, 143 ,33],
["NGC3198", 660, 30.80, 171, 55],
["M95" ,783 ,30.01 ,234 ,56],
["M96", 899 ,30.32 ,234 ,57],
["NGC3621" ,734 ,29.10,281 ,26],
["M100", 1590, 31.04, 271 ,77],
["NGC4414" ,720 ,31.41 ,175 ,83],
["NGC4496" ,1738 ,31.03, 291 ,66],
["NGC4535" ,1966 ,31.02 ,290 ,71],
["NGC4536", 1866 ,31.10, 293 ,65],
["NGC4548" ,472, 31.08, 286, 77],
["NGC4639",983 ,32.03 ,294, 76],
["NGC4725", 1207, 30.50 ,296 ,88],
["NGC5253", 417, 28.06 ,315 ,30],
["M101", 231,29.34, 102, 60],
["NGC7331", 819,30.89,94 ,-21],
["IC4182" ,326 ,28.36, 108, 79]]
G=np.array(ginga)
print(G)
x=[]
y=[]
for i in range(20):
  bv=float(G[i,2])
  x.append(10**(-(bv+5)/5)) #pc
  y.append(float(G[i,1]))
plt.scatter(y,y)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cat /TA/MyDrive/utyuakga/hipparcos.txt

# %%
import time


g=0
for i in range(1000):
  print(time.time())
  for j in range(1000):
    for k in range(1000):
      print(time.time())
      for l in range(1000):
        g+=i+j+k+l
print(g)

# %%
pwd

# %%
ls

# %%
a=[412,532,4,6,6,4231,7]
print(min(a))

# %%
help('modules')

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Generate some sample data
np.random.seed(42)
x = np.random.rand(100)
y = np.random.rand(100)
z = np.random.rand(100)

# Create the 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z)

# Set labels for the axes
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.animation import FuncAnimation

# 3Dデータの生成
x = np.random.rand(50) * 10
y = np.random.rand(50) * 10
z = np.random.rand(50) * 10

# FigureオブジェクトとAxes3Dオブジェクトの生成
fig = plt.figure()
ax = Axes3D(fig)

# 初期状態でのプロット
scatter = ax.scatter(x, y, z)

# アニメーションのコールバック関数
def update(i):
    # プロットを一旦削除
    scatter.remove()

    # データを更新
    x = np.random.rand(50) * 10
    y = np.random.rand(50) * 10
    z = np.random.rand(50) * 10

    # プロットを更新
    scatter = ax.scatter(x, y, z)

    # グラフを回転
    ax.view_init(elev=10., azim=i)

# アニメーションの作成
ani = FuncAnimation(fig, update, frames=range(0, 360, 10), interval=50)

# アニメーションの表示
plt.show()

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# データの準備
x = [1, 2, 3, 4, 5]
y = [2, 4, 1, 5, 2]
z = [1, 3, 2, 4, 1]

# 3Dグラフの作成
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z)

# マウスでグラフを動かす
ax.view_init(elev=30, azim=120)
plt.show()
