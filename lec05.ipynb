# %%
from google.colab import drive
drive.mount("/TA")
drive.mount("https://drive.google.com/file/d/1DCf29HFpXDkHFBR4o8XKW-y3_2oIPald/view?usp=sharing")
# Out:
# Mounted at /TA
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-aa60c8efb56a> in <module>()
#       1 from google.colab import drive
#       2 drive.mount("/TA")
# ----> 3 drive.mount("https://drive.google.com/file/d/1DCf29HFpXDkHFBR4o8XKW-y3_2oIPald/view?usp=sharing")
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms)
#     107       force_remount=force_remount,
#     108       timeout_ms=timeout_ms,
# --> 109       ephemeral=True)
#     110
#     111
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral)
#     186     normed = _os.path.normpath(mountpoint)
#     187     if '/' in normed and not _os.path.exists(_os.path.dirname(normed)):
# --> 188       raise ValueError('Mountpoint must be in a directory that exists')
# ...

# %%
ls /TA/MyDrive/utyuakga/
# Out:
# evs_cat.dat  hipparcos.dat  ngc1754.dat      pleiades.dat  sdss.dat
# example.dat  hipparcos.txt  opencluster.txt  praesepe.dat  zcat.dat

# %%
import matplotlib . pyplot as plt
import math
ld = open ("/TA/MyDrive/utyuakga/hipparcos.dat")
lines = ld.readlines ()
ld.close ()
x = []
y = []
for line in lines :
    vapp = float ( line [129:136])
    bv = float ( line [152:158])
    d=1000/float(line[43:50])
    v=vapp+5-5*math.log10(d)
    if bv != 0.:
        x.append (bv)
        y.append (v)
plt. xlim ( -0.5 ,2.5)
plt. ylim (16 , -2)
plt. scatter (x,y,s =1)
plt. show ()

# %%
import matplotlib . pyplot as plt
import math
ld = open ("/TA/MyDrive/utyuakga/hipparcos.dat")
lines = ld.readlines ()
ld.close ()
x = []
y = []
for line in lines :
    vapp = float ( line [129:136])
    bv = float ( line [152:158])
    d=1000/float(line[43:50])
    v=vapp+5-5*math.log10(d)
    if bv != 0.:
        x.append (bv)
        y.append (v)

ld2 = open ("/TA/MyDrive/utyuakga/praesepe.dat")
lines2 = ld2.readlines ()
ld2.close ()
xs = []
ys = []
d1=150
for line in lines2 :
    vapp = line [12:19]
    bv = line [20:27]
    if vapp != "       " and bv != "       ":
        xs.append (float(bv))
        ys.append (float(vapp)+5-5*math.log10(d1))
plt. xlim ( -0.5 ,2.5)
plt. ylim (16 , -2)
plt.xlabel('mB-mV')
plt.ylabel('mV, MV')
plt.scatter(x,y,s=1,label="hipparcos")
plt.scatter(xs,ys,s=1,label="praesepe")
plt.legend(bbox_to_anchor=(0.99,0.99),loc='upper right',fontsize=12)
plt.show()

# %%
import matplotlib . pyplot as plt
import math
ld = open ("/TA/MyDrive/utyuakga/hipparcos.dat")
lines = ld.readlines ()
ld.close ()
x = []
y = []
for line in lines :
    vapp = float ( line [129:136])
    bv = float ( line [152:158])
    d=1000/float(line[43:50])
    v=vapp+5-5*math.log10(d)
    if bv != 0.:
        x.append (bv)
        y.append (v)

ld2 = open ("/TA/MyDrive/utyuakga/pleiades.dat")
lines2 = ld2.readlines ()
ld2.close ()
xs = []
ys = []
d1=130
for line in lines2 :
    vapp = line [12:19]
    bv = line [20:27]
    if vapp != "       " and bv != "       ":
        xs.append (float(bv))
        ys.append (float(vapp)+5-5*math.log10(d1))
plt. xlim ( -0.5 ,2.5)
plt. ylim (16 , -2)
plt.xlabel('mB-mV')
plt.ylabel('mV, MV')
plt.scatter(x,y,s=1,label="hipparcos")
plt.scatter(xs,ys,s=1,label="pleiades")
plt.legend(bbox_to_anchor=(0.99,0.99),loc='upper right',fontsize=12)
plt.show()

# %%
import matplotlib . pyplot as plt
import math
ld = open ("/TA/MyDrive/utyuakga/hipparcos.dat")
lines = ld.readlines ()
ld.close ()
x = []
y = []
for line in lines :
    vapp = float ( line [129:136])
    bv = float ( line [152:158])
    d=1000/float(line[43:50])
    v=vapp+5-5*math.log10(d)
    if bv != 0.:
        x.append (bv)
        y.append (v)
plt. xlim ( -0.5 ,2.5)
plt. ylim (16 , -2)
plt. scatter (x,y,s =1)
plt. show ()

# %%
import matplotlib . pyplot as plt
import math
ld = open ("/TA/MyDrive/utyuakga/hipparcos.dat")
lines = ld.readlines ()
ld.close ()
x = []
y = []
samin=10000
samax=0
for line in lines :
    sa = float ( line [43:50])
    if sa<samin:
        samin=sa  
        print(samin,samax,line)
    if sa>samax:
        samax=sa  
        print(samin,samax,line)
# Out:
# 65.24 0    169| 15|3|2| 0.0093378862 -1.1917144126|  65.24|  209.95| -229.66|  1.75|  1.33|  1.76|  2.16|  1.56|154| 5.26| 0|   0.0|   0| 9.3369|0.0025|0.025|0| 1.390|0.042| 1.650|   1.12   0.19   1.05  -0.05   0.09   1.00   0.27  -0.02   0.04   1.01   0.03   0.25  -0.05   0.12   1.00
#
# 65.24 65.24    169| 15|3|2| 0.0093378862 -1.1917144126|  65.24|  209.95| -229.66|  1.75|  1.33|  1.76|  2.16|  1.56|154| 5.26| 0|   0.0|   0| 9.3369|0.0025|0.025|0| 1.390|0.042| 1.650|   1.12   0.19   1.05  -0.05   0.09   1.00   0.27  -0.02   0.04   1.01   0.03   0.25  -0.05   0.12   1.00
#
# 65.24 82.17    171|  1|2|1| 0.0094280686  0.4727135123|  82.17|  780.22| -917.75|  1.85|  1.26|  2.23|  2.01|  1.20|106| 0.13| 0|  10.1|   0| 5.8735|0.0009|0.007|0| 0.690|0.015| 0.820|   1.04  -0.13   1.04  -0.06  -0.07   1.01   0.08  -0.06   0.01   1.02  -0.10   0.22  -0.10  -0.19   1.00
#
# ...

# %%
import matplotlib . pyplot as plt
import math
ld = open ("/TA/MyDrive/utyuakga/hipparcos.dat")
lines = ld.readlines ()
ld.close ()
x = []
y = []
for line in lines :
    vapp = float ( line [129:136])
    bv = float ( line [165:171])
    d=1000/float(line[43:50])
    v=vapp+5-5*math.log10(d)
    if d<25:
        if bv != 0.:
            x.append (bv)
            y.append (vapp)
ld = open ("/TA/MyDrive/utyuakga/ngc1754.dat")
lines = ld.readlines ()
ld.close ()
x2 = []
y2 = []
d2=40000

for line in lines :
    bv2 = float ( line [74:82])
    bi2 = float ( line [83:91])
    #vi=bv2-bi2
    if bv2 != -999 and bi2 != -999:
            vi=bv2-bi2
            x2.append (vi+0.4)
            #x2.append (vi)
            y2.append (bv2+5-5*math.log10(d2))           
            
            
#plt. xlim ( -2 ,4)
#plt. ylim (30 , -2)
plt. scatter (x,y,s =1)
plt. scatter (x2,y2,s =1)
plt. show ()

# %%
import matplotlib . pyplot as plt
import math
ld = open ("/TA/MyDrive/utyuakga/hipparcos.dat")
lines = ld.readlines ()
ld.close ()
x = []
y = []
for line in lines :
    vapp = float ( line [129:136])
    bv = float ( line [165:171])
    d=1000/float(line[43:50])
    v=vapp+5-5*math.log10(d)
    if d<25:
        if bv != 0.:
            x.append (bv)
            y.append (v)
ld = open ("/TA/MyDrive/utyuakga/ngc1754.dat")
lines = ld.readlines ()
ld.close ()
x2 = []
y2 = []
d2=50000

for line in lines :
    bv2 = float ( line [74:82])
    bi2 = float ( line [83:91])
    vi=bv2-bi2
    if bv2 != -999 and bi2 != -999:
            x2.append (vi+0.4)
            #x2.append (vi)
            y2.append (bv2+5-5*math.log10(d2))           
            
            
plt. xlim ( -2 ,4)
plt. ylim (30 , -2)
plt. scatter (x,y,s =1)
plt. scatter (x2,y2,s =1)
plt. show ()

# %%
#出典
#データファイル 
#銀河識別番号 見かけの最大光度 (等級) 変光周期 (日)
#General Catalog of Variable Stars
#dataLec05/evs_cat.dat
#1-3 文字目 48-52 文字目 78-90 文字目

# %%
import matplotlib . pyplot as plt
import math
ld = open ("/TA/MyDrive/utyuakga/evs_cat.dat")
lines = ld.readlines ()
ld.close ()
x = []
y = []
x2 = []
y2 = []
d=17*d2
d2=45000
for line in lines :
    id=line[0:3]
    #print(id)
    if id=="089":
        x.append (float(line[77:90]))
        y.append (float(line[47:52])+5-5*math.log10(d2))
    if id=="091":
        x2.append (float(line[77:90]))
        y2.append (float(line[47:52])+5-5*math.log10(d))       
            
plt. xlim ( 0.5 ,2000)
#plt. ylim (25 , 10)
plt.xscale("log")
plt. scatter (x,y,s =1)
plt. scatter (x2,y2,s =1)
plt. show ()
print(d/1000,d2/1000,5-5*math.log10(d))
# Out:
# 850.0 45.0 -24.647094628571466

# %%
#v = H0r

# %%
import matplotlib . pyplot as plt
import numpy as np
import math
id=["M31","NGC300", "M33", "NGC925", " NGC1365 ", "NGC2090", "NGC2403", " NGC2541", " M81", "NGC3109", "NGC3198", " M95", "M96 ", "NGC3621", "M100", "NGC4414", "NGC4496", " NGC4535", " NGC4536", "NGC4548", " NGC4639", "NGC4725","NGC5253","M101","NGC7331","IC4182"]
v=[-298,145,-182, 554, 1639, 936 ,132 ,553, -43, 403, 660, 783, 899, 734, 1590, 720, 1738, 1966, 1866, 472, 983, 1207, 417, 231, 819, 326]
mag=[24.4 ,26.66, 24.64, 29.84, 31.35, 30.45 ,27.51, 30.47 ,27.80 ,25.00 ,30.80 ,30.01 ,30.32, 29.10, 31.04 ,31.41 ,31.03 ,31.02 ,31.10 ,31.08 ,32.03 ,30.50 ,28.06 ,29.34 ,30.89 ,28.36]
deg1=[121,299,134,144,238,239,150,170,143,262,171,234,234,281,271,175,291,290,293,286,294,296,315,102,94,108]
deg2=[-22,-79,-31,-25,-55,-27,29, 33, 33, 23, 55, 56, 57, 26, 77, 83 ,66 ,71 ,65 ,77 ,76, 88, 30, 60 ,-21 ,79]
x=[]
y=[]

print(len(id))
for i in range(len(id)):
    #print(i,id[i],int(v[i]),float(mag[i]),int(deg1[i]),int(deg2[i]))
    x.append(10**((float(mag[i]))-5)/5) #i=>r
    y.append(int(v[i]))
    #print(10**((float(mag[i])-5)/5),int(v[i]),mag[i])

#plt. xlim ( 10**17,10**27)
plt. ylim (20 , 4000)
plt.xscale("log")
plt.yscale("log")
plt. scatter (x,y,s =1)


A = np.array([x,np.ones(len(x))])
A = A.T
a,b = np.linalg.lstsq(A,y)[0]
print(a,b)
plt.plot(x,(26.*x),"g--")

x2=np.logspace(start=16,stop=30,num=200)
for i in range(10):
    #po=(i+30)/300
    #y2=np.power(x2,po)
    H=1*10**(-(15+i))
    y2=x2*H
    #print(x2)
    #print(x2,y2)
    #plt. plot (x2,y2,linewidth=0.5,label=str(format(po, '.3f')))
    plt. plot (x2,y2,linewidth=0.5,label=str(15+i))

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0, fontsize=8)
plt. show ()
H=1e-22
# Out:
# 26
# 9.988461696840096e-24 8.899395426937247e-50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-73c3ba388b82> in <module>()
#      28 a,b = np.linalg.lstsq(A,y)[0]
#      29 print(a,b)
# ---> 30 plt.plot(x,(26.*x),"g--")
#      31
#      32 x2=np.logspace(start=16,stop=30,num=200)
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
import matplotlib . pyplot as plt
import numpy as np
import math
id=["M31","NGC300", "M33", "NGC925", " NGC1365 ", "NGC2090", "NGC2403", " NGC2541", " M81", "NGC3109", "NGC3198", " M95", "M96 ", "NGC3621", "M100", "NGC4414", "NGC4496", " NGC4535", " NGC4536", "NGC4548", " NGC4639", "NGC4725","NGC5253","M101","NGC7331","IC4182"]
v=[-298,145,-182, 554, 1639, 936 ,132 ,553, -43, 403, 660, 783, 899, 734, 1590, 720, 1738, 1966, 1866, 472, 983, 1207, 417, 231, 819, 326]
mag=[24.4 ,26.66, 24.64, 29.84, 31.35, 30.45 ,27.51, 30.47 ,27.80 ,25.00 ,30.80 ,30.01 ,30.32, 29.10, 31.04 ,31.41 ,31.03 ,31.02 ,31.10 ,31.08 ,32.03 ,30.50 ,28.06 ,29.34 ,30.89 ,28.36]
deg1=[121,299,134,144,238,239,150,170,143,262,171,234,234,281,271,175,291,290,293,286,294,296,315,102,94,108]
deg2=[-22,-79,-31,-25,-55,-27,29, 33, 33, 23, 55, 56, 57, 26, 77, 83 ,66 ,71 ,65 ,77 ,76, 88, 30, 60 ,-21 ,79]
x=[]
y=[]

print(len(id))
for i in range(len(id)):
    #print(i,id[i],int(v[i]),float(mag[i]),int(deg1[i]),int(deg2[i]))
    x.append(10**((float(mag[i]))-5)/5) #i=>r
    y.append(int(v[i]))
    #print(10**((float(mag[i])-5)/5),int(v[i]),mag[i])

#plt. xlim ( 10**17,10**27)
plt. ylim (20 , 4000)
plt.xscale("log")
plt.yscale("log")
plt. scatter (x,y,s =1)
x2=np.logspace(start=16,stop=30,num=200)
vx=y*np.cos(deg1)
vy=y*np.sin(deg1)+200
vnew=np.power(vx**2+vy**2,0.5)
print(y)
print(vnew)
plt. scatter (x,vnew,s =1)
'''for i in range(10):
    #po=(i+30)/300
    #y2=np.power(x2,po)
    H=1*10**(-(15+i))
    y2=x2*H
    #print(x2)
    #print(x2,y2)
    #plt. plot (x2,y2,linewidth=0.5,label=str(format(po, '.3f')))
    plt. plot (x2,y2,linewidth=0.5,label=str(15+i))'''

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0, fontsize=8)
plt. show ()
H=1e-22
# Out:
# No handles with labels found to put in legend.
# 26
# [-298, 145, -182, 554, 1639, 936, 132, 553, -43, 403, 660, 783, 899, 734, 1590, 720, 1738, 1966, 1866, 472, 983, 1207, 417, 231, 819, 326]
# [  98.71790726  175.42391555   92.89065271  487.96066931 1508.03492672
#  1002.35372552  140.28016437  649.99066113  242.9414337   222.58566087
#   856.39943317  982.81147108 1098.80638975  538.0664813  1741.95926492
#   572.42749461 1923.60024162 2134.33535475 1723.43156944  491.02644891
#   791.46355079 1343.23390806  581.53007534  430.44511325  793.98768854
#   516.84923634]

# %%
import matplotlib . pyplot as plt
import math
ld = open ("/TA/MyDrive/utyuakga/hipparcos.dat")
lines = ld.readlines ()
ld.close ()
x = []
y = []
#for line in lines :
    #print(line[43:50])

# %%
import matplotlib . pyplot as plt
import math
import numpy as np
ld = open ("/TA/MyDrive/utyuakga/zcat.dat")
lines = ld.readlines ()
ld.close ()
x = []
y = []
i=0
for line in lines :
  #if i==100:
  if line[11:13]=='  ' or line[13:15]=='  ' or line[15:19]=='    ' or line[19:22]=='   ' or line[22:24]=='  '  or line[31:36]=='     ':
    print(line[11:13])
    print(line[13:15])
    print(line[15:19])
    print(line[19:22])
    print(line[22:24])
    print(line[31:36])
  i+=1
# Out:
# 08
# 50
# 48.0
#  72
# 12
#
# 09
# 37
# 11.9
#  17
# 00
#
# 10
# 02
# 12.0
#  68
# 03
#
# 10
# 04
# 41.5
#  70
# 49
#
# 11
# 45
# 50.6
#  26
# 02
#
# 11
# 45
# 51.7
#  26
# 02
#
# 12
# 31
# 44.9
#  82
# 50
#
# 14
# 30
# 20.6
#  01
# 45
#
# 14
# 49
# 02.0
#  06
# 16
#
# 15
# 10
# 42.1
#  04
# 28
#
# 15
# 13
# 31.1
#  00
# 04
#
# 16
# 33
# 42.5
#  79
# 03
#
# 17
# 36
# 10.4
#  11
# 48
#
# 18
# 09
# 52.8
#  35
# 59
#
# 18
# 39
# 10.4
#  08
# 05

# %%
import matplotlib . pyplot as plt
import math
import numpy as np
ld = open ("/TA/MyDrive/utyuakga/sdss.dat")
lines = ld.readlines ()
ld.close ()
x = []
y = []
datas=[0,2,3,5,6,11,12,15,16,18,19,23,24,30]
i=0
gin=[]
for line in lines :
  #if i==100:
  #if line[datas[0]:datas[1]]==' '*-(datas[0]-datas[1]) or line[datas[2]:datas[3]]==' '*-(datas[2]-datas[3]) or line[datas[4]:datas[5]]=='    ' or line[datas[6]:datas[7]]=='   ' or line[datas[8]:datas[9]]=='  '  or line[datas[10]:datas[11]]=='     ' or line[datas[11]:datas[12]]=='     ':
    #print (line[0:2] )
    if line[0:2] != '  ' :
      a=float((line[0:2]))
      gin.append(a)
    #print(line[11:13])
    #print(line[13:15])
    #print(line[15:19])
    #print(line[19:22])
    #print(line[22:24])
    #print(line[31:36])
  #i+=1
gin=np.array(gin)
#print(gin)
for time in range(30):
  print(time,np.count_nonzero(gin==time))
# Out:
# 0 25509
# 1 23738
# 2 21939
# 3 11124
# 4 3374
# 5 603
# 6 0
# 7 0
# 8 0
# 9 2416
# 10 20971
# 11 20680
# 12 16728
# 13 16470
# 14 9777
# 15 0
# 16 0
# 17 0
# 18 0
# 19 0
# 20 348
# 21 8983
# 22 28019
# 23 26650
# 24 0
# 25 0
# 26 0
# 27 0
# 28 0
# 29 0

# %%
print(math.degrees(math.pi))
# 180.0

print(math.radians(180))
# 3.141592653589793
# Out:
# 180.0
# 3.141592653589793

# %%
X=np.arange(100)
Y=np.arange(100)

plt.scatter(X,Y)

# %%
a=10.3
str(a)
plt.plot(1,a)

# %%
import numpy as np
a=[4,5,6,2,46,7,2,5,3,2,5,32,6,7]
b=np.power(a,4)
plt.scatter(a,b)

# %%
import matplotlib.pyplot as plt
import numpy as np
import time


def generate(X, Y, phi):
    """
    Generates Z data for the points in the X, Y meshgrid and parameter phi.
    """
    R = 1 - np.sqrt(X**2 + Y**2)
    return np.cos(2 * np.pi * X + phi) * R


fig = plt.figure()
ax = fig.add_subplot(projection='3d')

# Make the X, Y meshgrid.
xs = np.linspace(-1, 1, 50)
ys = np.linspace(-1, 1, 50)
X, Y = np.meshgrid(xs, ys)

# Set the z axis limits so they aren't recalculated each frame.
ax.set_zlim(-1, 1)

# Begin plotting.
wframe = None
tstart = time.time()
for phi in np.linspace(0, 180. / np.pi, 100):
    # If a line collection is already remove it before drawing.
    if wframe:
        wframe.remove()

    # Plot the new wireframe and pause briefly before continuing.
    Z = generate(X, Y, phi)
    wframe = ax.plot_wireframe(X, Y, Z, rstride=2, cstride=2)
    plt.pause(.001)

print('Average FPS: %f' % (100 / (time.time() - tstart)))
# Out:
# Average FPS: 73.011334

# %%
import matplotlib.pyplot as plt
x = [1,2,3]
y = [1,2,3]
plt.plot=(x,y)
plt.show()
